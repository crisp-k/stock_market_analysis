# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data/silver-historical-prices.csv')

# %%
data.head()
# Out:
#      Exp Date Symbol                 Contract Name   Last  52W High  \
# 0  1980-01-28  SIF80   Silver January 1980 Futures  33.95     50.36
# 1  1980-02-26  SIG80  Silver February 1980 Futures  33.56     41.00
# 2  1980-03-26  SIH80     Silver March 1980 Futures  15.80     41.50
# 3  1980-04-25  SIJ80     Silver April 1980 Futures  14.90     39.00
# 4  1980-05-27  SIK80       Silver May 1980 Futures  13.50     42.00
#
#   52W High Date  52W Low 52W Low Date  52W %Chg        Time
# 0    1980-01-18    6.985   1979-01-30  +380.33%  1980-01-28
# 1    1980-01-21   18.242   1979-11-29   +83.97%  1980-02-26
# 2    1980-01-21    7.760   1979-04-17   +90.29%  1980-03-26
# 3    1980-02-11   10.200   1980-03-27   -59.46%  1980-04-25
# 4    1980-01-21    8.940   1979-06-13   +40.90%  1980-05-27

# %%
data.columns
# Out:
# Index(['Exp Date', 'Symbol', 'Contract Name', 'Last', '52W High',
#        '52W High Date', '52W Low', '52W Low Date', '52W %Chg', 'Time'],
#       dtype='object')

# %%
plt.scatter(x=data['Exp Date'], y=data['Last'])

plt.show()

# %%
print(data.shape)

years_2010_2023 = data[data['Exp Date'] >= '2010-01-01']
# Out:
# (543, 10)

# %%
years_2010_2023.shape
years_2010_2023.head()

plt.plot(years_2010_2023['Exp Date'], years_2010_2023['Last'])

plt.show()

# %%
years_2010_2023['Last'].plot()
# Out:
# <Axes: >

# %%
data.iloc[0]
# Out:
# Exp Date                          1980-01-28
# Symbol                                 SIF80
# Contract Name    Silver January 1980 Futures
# Last                                   33.95
# 52W High                               50.36
# 52W High Date                     1980-01-18
# 52W Low                                6.985
# 52W Low Date                      1979-01-30
# 52W %Chg                            +380.33%
# Time                              1980-01-28
# Name: 0, dtype: object

# %%
data['Exp Date'] = pd.to_datetime(data['Exp Date'], format='mixed')

data.head()
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# c:\Users\kylec\OneDrive\Desktop\ML\stocks\stock_analysis.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kylec/OneDrive/Desktop/ML/stocks/stock_analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> data['Exp Date'] = pd.to_datetime(data['Exp Date'], format='mixed')
#       <a href='vscode-notebook-cell:/c%3A/Users/kylec/OneDrive/Desktop/ML/stocks/stock_analysis.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> data.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# ...
